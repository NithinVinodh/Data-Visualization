# %%
# !pip install pandas
# !pip install seaborn
# Out:
# ...
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import seaborn as sns

# %%
data=pd.read_csv("iplauction2023.csv")
data
# Out:
#                 name player style   nationality  base price (in lacs)  \
# 0       Harshit Rana       Bowler         India                   NaN
# 1          Ekant Sen       Batter         India                  20.0
# 2      Wayne Parnell   Allrounder  South Africa                  75.0
# 3    Shakib Al Hasan   Allrounder    Bangladesh                 150.0
# 4           Joe Root       Batter       England                 100.0
# ..               ...          ...           ...                   ...
# 304         MS Dhoni    WK-Batter         India                   NaN
# 305        Moeen Ali   Allrounder       England                   NaN
# 306  Ruturaj Gaikwad       Batter         India                   NaN
# 307     Rishabh Pant    WK-Batter         India                   NaN
# 308       Axar Patel   Allrounder         India                   NaN
#
#      final price (in lacs) franchise    status
# 0                     20.0       KKR  RETAINED
# ...

# %%
player_style_counts = data['player style'].value_counts()
custom_colors = ['red','green','orange','blue']
plt.figure(figsize=(10, 6))
player_style_counts.plot(kind='bar', color=custom_colors)
plt.title('Player Style Distribution in IPL Auction 2023')
plt.xlabel('Player Style')
plt.ylabel('Count')
plt.xticks(rotation=45)  
plt.tight_layout() 
plt.show()

# %%
nationality_counts = data['nationality'].value_counts()
specified_countries = ['India', 'England', 'South Africa', 'West Indies', 'Australia', 'New Zealand', 'Sri Lanka']
specified_countries_counts = nationality_counts[nationality_counts.index.isin(specified_countries)]
others_count = nationality_counts[~nationality_counts.index.isin(specified_countries)].sum()
specified_countries_counts['Others'] = others_count
plt.figure(figsize=(8, 8))
plt.pie(specified_countries_counts, labels=specified_countries_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Nationality Distribution of Players in IPL Auction 2023')
plt.axis('equal')
plt.show()

# %%
custom_colors = ['skyblue', 'orange', 'green', 'red', 'purple']
plt.figure(figsize=(10, 8))
plt.barh(df_sorted['name'].head(5), df_sorted['final price (in lacs)'].head(5), color=custom_colors)
plt.xlabel('Auction Price (in lakhs)')
plt.ylabel('Player Name')
plt.title('Top 5 Auction Prices of Players in IPL Auction 2023')
plt.gca().invert_yaxis()  # Invert y-axis to display highest-paid players at the top
plt.show()

# %%
players_per_team = data['franchise'].value_counts()
custom_colors = ['skyblue', 'orange', 'green', 'red', 'purple', 'yellow', 'pink', 'cyan', 'magenta', 'brown']
plt.figure(figsize=(10, 6))
players_per_team.plot(kind='bar', color=custom_colors)
plt.title('Number of Players Selected in Each Team')
plt.xlabel('Team')
plt.ylabel('Number of Players Selected')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(data['final price (in lacs)'], data['player style'], color='green', alpha=0.6)
plt.title('Scatter Plot: Auction Price vs. Performance Metric')
plt.xlabel('Auction Price')
plt.ylabel('player style')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
data.boxplot(column='final price (in lacs)', by='player style', figsize=(10,6))
plt.title('Distribution of Auction Prices by Player Role')
plt.xlabel('Player Role')
plt.ylabel('Auction Price (in lakhs)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
